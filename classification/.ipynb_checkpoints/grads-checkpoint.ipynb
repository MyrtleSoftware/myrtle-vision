# %%
import numpy as np

# %%
vector1 = np.array([100, 3, 1, 0])
vector2 = np.array([1, -5, 0, 3])

# %%
a = np.dot(vector1, vector2)/np.linalg.norm(vector2)**2
a
# Out:
# 2.4285714285714284

# %%
vector3 = vector1 - a*vector2

# %%
vector3
# Out:
# array([97.57142857, 15.14285714,  1.        , -7.28571429])

# %%
np.dot(vector2, vector3)
# Out:
# 7.105427357601002e-15

# %%
a*vector2 + vector3
# Out:
# array([100.,   3.,   1.,   0.])
