# %%
import numpy as np

# %%
vector1 = np.array([100, 3, 1, -999])
vector2 = np.array([-300, -5, 70, 3])

# %%
a = np.dot(vector1, vector2)/np.linalg.norm(vector2)**2
a
# Out:
# -0.34699896770387845

# %%
vector3 = vector1 - a*vector2

# %%
vector3
# Out:
# array([  -4.09969031,    1.26500516,   25.28992774, -997.9590031 ])

# %%
np.dot(vector2, vector3)
# Out:
# -5.4569682106375694e-12

# %%
a*vector2 + vector3
# Out:
# array([ 100.,    3.,    1., -999.])

# %%
np.linalg.norm(vector3)
# Out:
# 998.2886155846409

# %%
vector4 = vector3 / np.linalg.norm(vector3)
vector4
# Out:
# array([-0.00410672,  0.00126717,  0.02533328, -0.99966982])

# %%
np.linalg.norm(vector4)
# Out:
# 1.0
